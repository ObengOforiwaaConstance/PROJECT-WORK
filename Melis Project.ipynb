# %% [markdown]
# <h1 style="text-align: center;" >PROJECT I : Dataset of all inventories of red wine </h1>

# %% [markdown]
# ## Full Name: Constance Obeng Oforiwaa
# ## ID : 10951437
# ## Department: Materials science and Engineering
#
# ---
#
# <h2 style="text-align: center;">Table of content </h2>
#
# ### 1. Pre-processing  of the data
# ### 2. Statistical inferences of the entire dataset
# ### 3. Statistical inferences of individuals columns
# ### 4. Statistical Correlation and Heatmap
#
# ---

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')

# %%
# Primary Dataset
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.076                 11.0                  34.0  0.99780  3.51
# 1         0.098                 25.0                  67.0  0.99680  3.20
# 2         0.092                 15.0                  54.0  0.99700   NaN
# 3         0.075                 17.0                  60.0  0.99800  3.16
# 4         0.076                 11.0                  34.0  0.99780  3.51
# ...         ...                  ...                   ...      ...   ...
# 1596      0.062                 39.0                  51.0  0.99512  3.52
# 1597      0.076                 29.0                  40.0  0.99574  3.42
# 1598      0.075                 32.0                  44.0  0.99547  3.57
# 1599      0.067                 18.0                  42.0  0.99549  3.39
# 1600      0.066                 22.0                  48.0  0.99494  3.30
#
#       sulphates  alcohol  quality
# 0          0.56      9.4      5.0
# 1          0.68      9.8      5.0
# 2          0.65      9.8      5.0
# 3          0.58      9.8      6.0
# 4          0.56      9.4      5.0
# ...         ...      ...      ...
# 1596       0.76     11.2      6.0
# 1597       0.75     11.0      6.0
# 1598       0.71     10.2      5.0
# 1599       0.66     11.0      6.0
# 1600       0.84     11.5      6.0
#
# [1601 rows x 13 columns]

# %%
# Description of the entire primary dataset 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# ### 1- Pre-processing of the data

# %%
# checking for any empty value
data.isnull().any().any()
# Out:
# True

# %% [markdown]
# * There are missing value in the dataset

# %% [markdown]
# ### Event of Null Value with Dropna() method
# this method is being choose because in the above description the number of  empty data are not many.

# %%
data.dropna(inplace= True)

# %%
# Duplicate value in the dataset ?
data.duplicated()
# Out:
# 0       False
# 1       False
# 3       False
# 4       False
# 5       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Length: 1591, dtype: bool

# %%
# checking if there is correction
data.isnull().any().any()
# Out:
# False

# %% [markdown]
# * Not empty data find

# %%
# New dataset
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 
# 1575       0.48    10.50      6.0
# 1576       0.64    11.80      6.0
# 1577       0.78    10.80      6.0
# 1578       0.60    11.90      6.0
# 1579       0.67    11.30      6.0
# 1580       0.60    11.30      5.0
# 1581       0.60    11.90      6.0
# 1582       0.60    11.30      5.0
# 1583       0.50    11.90      5.0
# 1586       0.84    11.50      6.0
# 1587       0.85    11.40      6.0
# 1588       0.66    10.90      6.0
# 1589       0.78    12.80      6.0
# 1590       0.54     9.20      5.0
# 1591       0.82    11.60      6.0
# 1592       0.56    11.60      6.0
# 1593       0.75    11.00      6.0
# 1594       0.82     9.50      6.0
# 1596       0.76    11.20      6.0
# 1597       0.75    11.00      6.0
# 1598       0.71    10.20      5.0
# 1599       0.66    11.00      6.0
# 1600       0.84    11.50      6.0

# %% [markdown]
# * total dataset = 1591
# * datatype = float , int

# %%
data.drop_duplicates(inplace= True)

# %%
# post processing dataset description
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1591 non-null   int64
#  1   fixed acidity         1591 non-null   float64
#  2   volatile acidity      1591 non-null   float64
#  3   citric acid           1591 non-null   float64
#  4   residual sugar        1591 non-null   float64
#  5   chlorides             1591 non-null   float64
#  6   free sulfur dioxide   1591 non-null   float64
#  7   total sulfur dioxide  1591 non-null   float64
#  8   density               1591 non-null   float64
#  9   pH                    1591 non-null   float64
#  10  sulphates             1591 non-null   float64
#  11  alcohol               1591 non-null   float64
#  12  quality               1591 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 174.0 KB

# %% [markdown]
# ### 2- Statistical inferences of the entire dataset

# %%
# Renaming the colomns
data = data.rename(columns= {'fixed acidity' : 'fixed_acidity', 'volatile acidity' : 'volatile_acidity', 'citric acid' : 'citric_acid', 'residual sugar' : 'residual_sugar','free sulfur dioxide':'free_sulfur_dioxide', 'total sulfur dioxide':'total_sulfur_dioxide'})

# %%
data= data.loc[0:1601, ['fixed_acidity','volatile_acidity', 'citric_acid','residual_sugar', 'chlorides','free_sulfur_dioxide','total_sulfur_dioxide', 'density','pH','sulphates','alcohol','quality']]

# %%
data.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1591.000000       1591.000000  1591.000000     1591.000000
# mean        8.320616          0.527681     0.271477        2.540761
# std         1.740134          0.179045     0.194807        1.413076
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1591.000000          1591.000000           1591.000000  1591.000000
# mean      0.087500            15.861722             46.498429     0.996747
# std       0.047175            10.429385             32.998659     0.001889
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997845
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1591.000000  1591.000000  1591.000000  1591.000000
# mean      3.311358     0.658611    10.426053     5.637964
# std       0.154548     0.169786     1.066706     0.807772
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
plt.figure(figsize=(12,4), dpi= 300)
p= sns.scatterplot(data= data, palette= 'Dark2')
p.set(xlabel="Sample", ylabel = "Element concetration")
plt.show()

# %%
D= sns.histplot(data= data, bins =10 , binwidth=5, element= 'poly')
D.set(xlabel="quantitative composition", ylabel = "Total number ")
plt.show()

# %% [markdown]
# ### 3- Statistical inferences of individual columns
# #### a- Fixed acidity

# %%
data.fixed_acidity.describe()
# Out:
# count    1591.000000
# mean        8.320616
# std         1.740134
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed_acidity, dtype: float64

# %%
fixed_acidity_mean = data.fixed_acidity.mean()
y = data.fixed_acidity < fixed_acidity_mean
y.value_counts()
# Out:
# True     965
# False    626
# Name: fixed_acidity, dtype: int64

# %%
lb = ['Below fixed_acidity_mean','Above fixed_acidity_mean']
explode = [0,0.1]
color_values = ['b', 'r']
plt.pie(y.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below fixed_acidity_mean, Above fixed_acidity_mean')
plt.legend(y.value_counts())

# %%
sns.histplot(x= 'fixed_acidity', data = data, kde= True)
# Out:
# <Axes: xlabel='fixed_acidity', ylabel='Count'>

# %% [markdown]
# #### b- Volatile_acidity

# %%
data.volatile_acidity.describe()
# Out:
# count    1591.000000
# mean        0.527681
# std         0.179045
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile_acidity, dtype: float64

# %%
volatile_acidity_mean = data.volatile_acidity.mean()
z = data.volatile_acidity < volatile_acidity_mean
z.value_counts()
# Out:
# True     812
# False    779
# Name: volatile_acidity, dtype: int64

# %%
lb = ['Below volatile_acidity_mean','Above volatile_acidity_mean']
explode = [0,0.1]
color_values = ['y', 'm']
plt.pie(z.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below volatile_acidity_mean, Above volatile_acidity_mean')
plt.legend(z.value_counts())

# %%
sns.histplot(x= 'volatile_acidity',data= data, kde= True, bins = 20)
# Out:
# <Axes: xlabel='volatile_acidity', ylabel='Count'>

# %% [markdown]
# ### c- Citric_acid

# %%
data.citric_acid.describe()
# Out:
# count    1591.000000
# mean        0.271477
# std         0.194807
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric_acid, dtype: float64

# %%
citric_acid_mean = data.citric_acid.mean()
p = data.citric_acid < citric_acid_mean
p.value_counts()
# Out:
# True     847
# False    744
# Name: citric_acid, dtype: int64

# %%
lb = ['Below citric_acid_mean','Above citric_acid_mean']
explode = [0,0.1]
color_values = ['r', 'm']
plt.pie(p.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below citric_acid_mean, Above citric_acid_mean')
plt.legend(p.value_counts())

# %%
sns.histplot(x= 'citric_acid' ,data= data, kde= True, bins = 20)
# Out:
# <Axes: xlabel='citric_acid', ylabel='Count'>

# %% [markdown]
# ### d- Residual sugar

# %%
data.residual_sugar.describe()
# Out:
# count    1591.000000
# mean        2.540761
# std         1.413076
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual_sugar, dtype: float64

# %%
residual_sugar_mean = data.residual_sugar.mean()
q = data.residual_sugar < residual_sugar_mean
q.value_counts()
# Out:
# True     1156
# False     435
# Name: residual_sugar, dtype: int64

# %%
lb = ['Below','Above']
explode = [0,0.1]
color_values = ['g', 'y']
plt.pie(q.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below residual_sugar_mean, Above residual_sugar_mean')
plt.legend(q.value_counts())

# %%
sns.histplot(x= 'residual_sugar' , data = data, kde= True, bins = 20)
# Out:
# <Axes: xlabel='residual_sugar', ylabel='Count'>

# %% [markdown]
# ### e- Chlorides

# %%
data.chlorides.describe()
# Out:
# count    1591.000000
# mean        0.087500
# std         0.047175
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
chlorides_mean = data.chlorides.mean()
r = data.chlorides < chlorides_mean
r.value_counts()
# Out:
# True     1120
# False     471
# Name: chlorides, dtype: int64

# %%
lb = ['Below','Above']
explode = [0,0.1]
color_values = ['y', 'b']
plt.pie(r.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below chlorides_mean, Above chlorides_mean')
plt.legend(r.value_counts())

# %%
sns.histplot(x= 'chlorides',data= data, kde= True, bins = 20)
# Out:
# <Axes: xlabel='chlorides', ylabel='Count'>

# %% [markdown]
# ### f- Free_sulfur_dioxide

# %%
data.free_sulfur_dioxide.describe()
# Out:
# count    1591.000000
# mean       15.861722
# std        10.429385
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free_sulfur_dioxide, dtype: float64

# %%
free_sulfur_dioxide_mean = data.free_sulfur_dioxide.mean()
w = data.free_sulfur_dioxide < free_sulfur_dioxide_mean
w.value_counts()
# Out:
# True     918
# False    673
# Name: free_sulfur_dioxide, dtype: int64

# %%
lb = ['Below','Above']
explode = [0,0.1]
color_values = ['m', 'b']
plt.pie(w.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below free_sulfur_dioxide_mean, Above free_sulfur_dioxide_mean')
plt.legend(w.value_counts())

# %%
sns.histplot(x = 'free_sulfur_dioxide', data = data, kde= True, bins = 20)
# Out:
# <Axes: xlabel='free_sulfur_dioxide', ylabel='Count'>

# %% [markdown]
# ### g- Density

# %%
data.density.describe()
# Out:
# count    1591.000000
# mean        0.996747
# std         0.001889
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997845
# max         1.003690
# Name: density, dtype: float64

# %%
density_mean = data.density.mean()
f = data.density < density_mean
f.value_counts()
# Out:
# False    796
# True     795
# Name: density, dtype: int64

# %%
lb = ['Above','Below']
explode = [0,0.1]
color_values = ['g', 'r']
plt.pie(f.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below density_mean, Above density_mean')
plt.legend(f.value_counts())

# %%
sns.histplot(x= 'density', data = data, kde= True, bins = 20)
# Out:
# <Axes: xlabel='density', ylabel='Count'>

# %% [markdown]
# ### h- pH

# %%
data.pH.describe()
# Out:
# count    1591.000000
# mean        3.311358
# std         0.154548
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
pH_mean = data.pH.mean()
g = data.pH < pH_mean
g.value_counts()
# Out:
# True     817
# False    774
# Name: pH, dtype: int64

# %%
lb = ['Above','Below']
explode = [0,0.1]
color_values = ['y', 'm']
plt.pie(g.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below pH_mean, Above pH_mean')
plt.legend(g.value_counts())

# %%
sns.histplot(x= 'pH', data = data, kde= True, bins = 20)
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %% [markdown]
# ### i- Sulphates

# %%
data.sulphates.describe()
# Out:
# count    1591.000000
# mean        0.658611
# std         0.169786
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
sulphates_mean = data.sulphates.mean()
h = data.sulphates < sulphates_mean
h.value_counts()
# Out:
# True     956
# False    635
# Name: sulphates, dtype: int64

# %%
lb = ['Above','Below']
explode = [0,0.1]
color_values = ['c', 'm']
plt.pie(h.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below sulphates_mean, Above sulphates_mean')
plt.legend(h.value_counts())

# %%
sns.histplot(x= 'sulphates' , data= data , kde= True, bins = 20)
# Out:
# <Axes: xlabel='sulphates', ylabel='Count'>

# %% [markdown]
# ### g- Alcohol

# %%
data.alcohol.describe()
# Out:
# count    1591.000000
# mean       10.426053
# std         1.066706
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
alcohol_mean = data.alcohol.mean()
i = data.alcohol < alcohol_mean
i.value_counts()
# Out:
# True     910
# False    681
# Name: alcohol, dtype: int64

# %%
lb = ['Above','Below']
explode = [0,0.1]
color_values = ['y', 'c']
plt.pie(i.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= color_values)
plt.title('Below alcohol_mean, Above alcohol_mean')
plt.legend(i.value_counts())

# %%
sns.histplot(x= 'alcohol', data= data, kde= True, bins = 20)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %% [markdown]
# ### k- Quality

# %%
data.quality.describe()
# Out:
# count    1591.000000
# mean        5.637964
# std         0.807772
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
quality_mean = data.quality.mean()
x = data.quality < quality_mean
x.value_counts()
# Out:
# False    854
# True     737
# Name: quality, dtype: int64

# %%
lb = ['Low quality','High quality']
explode = [0,0.1]
plt.pie(x.value_counts(), labels= lb, autopct = '%.2f%%', explode= explode, colors= None)
plt.title('High quality vs Low quality')
plt.legend(x.value_counts())

# %%
sns.catplot(x='quality',data=data ,kind ='count')

# %%
plt.title('Histogram of index vs quality')
plt.hist(data.quality)
plt.ylabel('Index')
plt.xlabel('quality')
# Out:
# Text(0.5, 0, 'quality')

# %%
sns.histplot(data= data.quality, kde= True, bins = 20)
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %% [markdown]
# ### 4. Statistical Correlation and Heatmap

# %%
data_correlation= data.corr()

# %%
data_correlation
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.256737     0.672306
# volatile_acidity          -0.256737          1.000000    -0.551511
# citric_acid                0.672306         -0.551511     1.000000
# residual_sugar             0.114839          0.001336     0.143731
# chlorides                  0.093857          0.061202     0.204294
# free_sulfur_dioxide       -0.150261         -0.014598    -0.057619
# total_sulfur_dioxide      -0.110992          0.074132     0.038593
# density                    0.666876          0.022504     0.364181
# pH                        -0.683788          0.234251    -0.543230
# sulphates                  0.184937         -0.261872     0.313530
# alcohol                   -0.061167         -0.203490     0.109561
# quality                    0.124958         -0.389380     0.224263
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity               0.114839   0.093857            -0.150261
# volatile_acidity            0.001336   0.061202            -0.014598
# citric_acid                 0.143731   0.204294            -0.057619
# residual_sugar              1.000000   0.055471             0.187771
# chlorides                   0.055471   1.000000             0.006125
# free_sulfur_dioxide         0.187771   0.006125             1.000000
# total_sulfur_dioxide        0.201975   0.047543             0.667158
# density                     0.355780   0.200843            -0.018730
# pH                         -0.086375  -0.265845             0.066752
# sulphates                   0.004876   0.371465             0.051255
# alcohol                     0.041258  -0.221720            -0.072511
# quality                     0.013377  -0.129036            -0.049843
#
#                       total_sulfur_dioxide   density        pH  sulphates  \
# fixed_acidity                    -0.110992  0.666876 -0.683788   0.184937
# volatile_acidity                  0.074132  0.022504  0.234251  -0.261872
# citric_acid                       0.038593  0.364181 -0.543230   0.313530
# residual_sugar                    0.201975  0.355780 -0.086375   0.004876
# chlorides                         0.047543  0.200843 -0.265845   0.371465
# free_sulfur_dioxide               0.667158 -0.018730  0.066752   0.051255
# total_sulfur_dioxide              1.000000  0.072720 -0.068603   0.042240
# density                           0.072720  1.000000 -0.341037   0.149758
# pH                               -0.068603 -0.341037  1.000000  -0.198338
# sulphates                         0.042240  0.149758 -0.198338   1.000000
# alcohol                          -0.206855 -0.496873  0.204044   0.092036
# quality                          -0.184651 -0.174794 -0.058077   0.249878
#
#                        alcohol   quality
# fixed_acidity        -0.061167  0.124958
# volatile_acidity     -0.203490 -0.389380
# citric_acid           0.109561  0.224263
# residual_sugar        0.041258  0.013377
# chlorides            -0.221720 -0.129036
# free_sulfur_dioxide  -0.072511 -0.049843
# total_sulfur_dioxide -0.206855 -0.184651
# density              -0.496873 -0.174794
# pH                    0.204044 -0.058077
# sulphates             0.092036  0.249878
# alcohol               1.000000  0.475444
# quality               0.475444  1.000000

# %% [markdown]
# ### Heatmap of the Data_ correlation

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data_correlation, annot=True, cmap= 'Greens', cbar= True)
# Out:
# <Axes: >

# %% [markdown]
# * density has a strong positive correlation with residual sugar, whereas it has a strong negative correlation with alcohol.
# * pH & fixed acidity has negative correlation.
# * density & fixed acidity has positive correlation.
# * citric acid & fixed acidity has positive correlation.
# * citric acid & volatile acidity has negative correlation.
# * Free sulphur dioxide & total sulphur dioxide has positive correlation.
